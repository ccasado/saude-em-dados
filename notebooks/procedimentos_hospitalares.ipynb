# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import os

sns.set()


dados = pd.read_csv("https://raw.githubusercontent.com/ccasado/saude-em-dados/main/dados/A091141189_28_143_208.csv",
                    encoding="ISO-8859-1", skiprows=3, skipfooter=12, sep=';', quotechar='"', engine="python",
                    thousands=".", decimal=",")

# %%
dados_sort = dados[["Unidade da Federação", "2021/Mar"]].sort_values(by = "2021/Mar", ascending = False)
fig = plt.figure()
my_path = os.path.dirname(os.path.abspath("__file__"))
my_file = 'ph-202103.png'
ax = dados_sort.plot(x="Unidade da Federação", y = "2021/Mar", kind ="bar", figsize=(10,6), legend=None, color="#836fca")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R${x:,.2f}'))
ax.legend(fontsize=15)
plt.title("Valor dos procedimentos hospitalares pelo SUS", size=20, weight='bold' )
plt.xlabel("Estados", size = 15)
plt.ylabel("Valores", size = 16)
plt.xticks(rotation=80)
fig.savefig(os.path.join(my_path, my_file))

plt.show()

# %%
![Procedimentos_hospitalares_2021mar](ph-202103.png)
# Out:
# zsh:1: missing delimiter for 'g' glob qualifier
